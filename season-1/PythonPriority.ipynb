# %% [markdown]
# # اولویت عملگرها

# %%
# Level             Operator                        Description
# ----------------------------------------------------------------------------
# 18      ->        ()                     ->       Groping
# ----------------------------------------------------------------------------
# 17      ->        f()                    ->       Funcion call
# ----------------------------------------------------------------------------
# 16      ->        [index:index]          ->       Slicing 
# ----------------------------------------------------------------------------
# 15      ->        []                     ->       Array Subscription
# ----------------------------------------------------------------------------
# 14      ->        **                     ->       Exponential
# ----------------------------------------------------------------------------
# 13      ->        ~                      ->       Bitwise Not
# ----------------------------------------------------------------------------
# 12      ->        +    -                 ->       Unray Plus / minus
# ----------------------------------------------------------------------------
# 11      ->        *                      ->       Multiplication
#                   /                               Division 
#                   %                               Modulo
# ----------------------------------------------------------------------------
# 10      ->        +    -                 ->       Addition / Subraction
# ----------------------------------------------------------------------------
# 9       ->        <<                     ->       Bitwise Left Shift
#                   >>                              Bitwise Right Shift
# ----------------------------------------------------------------------------
# 8       ->        &                      ->       Bitwise AND
# ----------------------------------------------------------------------------
# 7       ->        ^                      ->       Bitwise XOR
# ----------------------------------------------------------------------------
# 6       ->        |                      ->       Bitwise OR
# ----------------------------------------------------------------------------
# 5       ->        in, not in, is, is not ->       Membership
#                   <, <=, >, >=                    Relatonal
#                   ==                              Equality
#                   !=                              Inequality
# ----------------------------------------------------------------------------
# 4       ->        not                    ->       Boolean NOT
# ----------------------------------------------------------------------------
# 3       ->        and                    ->       Boolean AND
# ----------------------------------------------------------------------------
# 2       ->        or                     ->       Boolean OR
# ----------------------------------------------------------------------------
# 1       ->        lambda                 ->       Lambda Expriyion
